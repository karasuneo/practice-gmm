# %%
import numpy as np
from sklearn.mixture import GaussianMixture
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.mixture import GaussianMixture

# %%
np.random.seed(0)
num_samples = 100
num_features = 5  # WiFiアクセスポイントの数
num_locations = 3  # 位置の数

# 各位置ごとに信号強度データを生成
data = []
labels = []
for location in range(num_locations):
    for _ in range(num_samples):
        signal_strength = np.random.normal(
            loc=location * 10, scale=5, size=num_features
        )
        data.append(signal_strength)
        labels.append(location)

data = np.array(data)
labels = np.array(labels)

# データの前処理
scaler = StandardScaler()
data = scaler.fit_transform(data)

# データを訓練用とテスト用に分割
X_train, X_test, y_train, y_test = train_test_split(
    data, labels, test_size=0.3, random_state=0
)

# GMMモデルの構築と訓練
gmm = GaussianMixture(n_components=num_locations, random_state=0)
gmm.fit(X_train)

# テストデータに対して位置を推定
y_pred = gmm.predict(X_test)

# 精度の評価
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")

# 各テストサンプルの推定位置を表示
for i, (true_label, pred_label) in enumerate(zip(y_test, y_pred)):
    print(
        f"Sample {i}: True Location = {true_label}, Predicted Location = {pred_label}"
    )
# Out:
# Accuracy: 31.11%
# Sample 0: True Location = 2, Predicted Location = 1
# Sample 1: True Location = 1, Predicted Location = 1
# Sample 2: True Location = 0, Predicted Location = 0
# Sample 3: True Location = 2, Predicted Location = 1
# Sample 4: True Location = 2, Predicted Location = 1
# Sample 5: True Location = 1, Predicted Location = 2
# Sample 6: True Location = 2, Predicted Location = 1
# Sample 7: True Location = 2, Predicted Location = 1
# Sample 8: True Location = 0, Predicted Location = 0
# Sample 9: True Location = 1, Predicted Location = 2
# Sample 10: True Location = 2, Predicted Location = 1
# Sample 11: True Location = 0, Predicted Location = 0
# Sample 12: True Location = 1, Predicted Location = 2
# Sample 13: True Location = 2, Predicted Location = 1
# Sample 14: True Location = 0, Predicted Location = 0
# Sample 15: True Location = 0, Predicted Location = 0
# Sample 16: True Location = 2, Predicted Location = 1
# Sample 17: True Location = 0, Predicted Location = 0
# ...
